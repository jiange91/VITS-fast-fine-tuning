# %%
# !mkdir pretrained_models

# !mkdir video_data
# !mkdir raw_audio
# !mkdir denoised_audio
# !mkdir custom_character_voice
# !mkdir segmented_character_voice
# Out:
# mkdir: cannot create directory ‘pretrained_models’: File exists
# mkdir: cannot create directory ‘video_data’: File exists
# mkdir: cannot create directory ‘raw_audio’: File exists
# mkdir: cannot create directory ‘denoised_audio’: File exists
# mkdir: cannot create directory ‘custom_character_voice’: File exists
# mkdir: cannot create directory ‘segmented_character_voice’: File exists

# %%
PRETRAINED_MODEL = "CJE" #@param ["CJE","CJ"]
if PRETRAINED_MODEL == "CJ":
  # !wget https://huggingface.co/spaces/sayashi/vits-uma-genshin-honkai/resolve/main/model/D_0-p.pth -O ./pretrained_models/D_0.pth
  # !wget https://huggingface.co/spaces/sayashi/vits-uma-genshin-honkai/resolve/main/model/G_0-p.pth -O ./pretrained_models/G_0.pth
  # !wget https://huggingface.co/spaces/sayashi/vits-uma-genshin-honkai/resolve/main/model/config.json -O ./configs/finetune_speaker.json
elif PRETRAINED_MODEL == "CJE":
  # !wget https://huggingface.co/spaces/Plachta/VITS-Umamusume-voice-synthesizer/resolve/main/pretrained_models/D_trilingual.pth -O ./pretrained_models/D_0.pth
  # !wget https://huggingface.co/spaces/Plachta/VITS-Umamusume-voice-synthesizer/resolve/main/pretrained_models/G_trilingual.pth -O ./pretrained_models/G_0.pth
  # !wget https://huggingface.co/spaces/Plachta/VITS-Umamusume-voice-synthesizer/resolve/main/configs/uma_trilingual.json -O ./configs/finetune_speaker.json
# Out:
# --2023-03-21 22:53:56--  https://huggingface.co/spaces/Plachta/VITS-Umamusume-voice-synthesizer/resolve/main/pretrained_models/D_trilingual.pth
# Resolving huggingface.co (huggingface.co)... 3.83.196.160, 3.216.111.67, 23.20.207.15, ...
# Connecting to huggingface.co (huggingface.co)|3.83.196.160|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/29/5d/295d23fc3473ffc28ea014d7ec0b90f855243fabec52341e452b17b57e1f4f89/920fb34bf3dc466e761996e787952a7bd53d4f6699561e9141bcbcf4f3f34092?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27D_trilingual.pth%3B+filename%3D%22D_trilingual.pth%22%3B&Expires=1679690258&Policy=__&Signature=U-tiBwDyzgAMo9Rtfdbb1MmlmS3g76GauXGXFjviKxrn2dbkjRqxP4HLWDUROeSWyq9AhVMO9wuNn1umfD120BtOZXnWdrDyvVw-CA7XYVNxfbo%7E3Nva3fj0yIgd6BK%7EryHmZ2oXgxZEkyZWuEabc09d6zrYlqp7ttbz0PC41HGYpDn866L3Bq7mVeccA10py-Za1pHH5cv1G52ddBAv4521e8pf-dgUjQccbnom1ZVFMKFfw5sAZKFOoQabvijw-vnE9kytCKcU78vd9nLGzev0bEAEyNQPhhjbwsnaAniCIuNcdYlZ86htp2biiCZNDGvVuw9L0Vq5Eud%7ECgF0eA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-03-21 22:53:56--  https://cdn-lfs.huggingface.co/repos/29/5d/295d23fc3473ffc28ea014d7ec0b90f855243fabec52341e452b17b57e1f4f89/920fb34bf3dc466e761996e787952a7bd53d4f6699561e9141bcbcf4f3f34092?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%
wav
#   inflating: ./custom_character_voice/Gary/Lec18.5-1076.wav
#   inflating: ./custom_character_voice/Gary/Lec1-207.wav
#   inflating: ./custom_character_voice/Gary/Lec18-429.wav
#   inflating: ./custom_character_voice/Gary/Lec19-381.wav
#   inflating: ./custom_character_voice/Gary/Lec4-677.wav
#   inflating: ./custom_character_voice/Gary/Lec9-819.wav
#   inflating: ./custom_character_voice/Gary/Lec18.5-521.wav
#   inflating: ./custom_character_voice/Gary/Lec17-53.wav
#   inflating: ./custom_character_voice/Gary/Lec15-335.wav
#   inflating: ./custom_character_voice/Gary/Lec10.5-643.wav
#   inflating: ./custom_character_voice/Gary/Lec7-705.wav
#   inflating: ./custom_character_voice/Gary/Lec18-41.wav
#   inflating: ./custom_character_voice/Gary/Lec19-279.wav
#   inflating: ./custom_character_voice/Gary/Lec3-652.wav
#   inflating: ./custom_character_voice/Gary/Lec9-462.wav
#   inflating: ./custom_character_voice/Gary/Lec7-636.wav
#   inflating: ./custom_character_voice/Gary/Lec15-36.wav
#   inflating: ./custom_character_voice/Gary/Lec19-612.wav
#   inflating: ./custom_character_voice/Gary/Lec10-719.wav
#   inflating: ./custom_character_voice/Gary/Lec16-553.wav
#   inflating: ./custom_character_voice/Gary/Lec10-116.wav
#   inflating: ./custom_character_voice/Gary/Lec12-567.wav
#   inflating: ./custom_character_voice/Gary/Lec2-248.wav
#   inflating: ./custom_character_voice/Gary/Lec15-349.wav
#   inflating: ./custom_character_voice/Gary/Lec15-124.wav
#   inflating: ./custom_character_voice/Gary/Lec10.5-1275.wav
#   inflating: ./custom_character_voice/Gary/Lec15-270.wav
#   inflating: ./custom_character_voice/Gary/Lec18-365.wav
#   inflating: ./custom_character_voice/Gary/Lec5-571.wav
#   inflating: ./custom_character_voice/Gary/Lec7-486.wav
#   inflating: ./custom_character_voice/Gary/Lec14-104.wav
#   inflating: ./custom_character_voice/Gary/Lec20-653.wav
#   inflating: ./custom_character_voice/Gary/Lec18-394.wav
#   inflating: ./custom_character_voice/Gary/Lec15-428.wav
#   inflating: ./custom_character_voice/Gary/Lec14-445.wav
#   inflating: ./custom_character_voice/Gary/Lec10-628.wav
#   inflating: ./custom_character_voice/Gary/Lec18-533.wav
#   inflating: ./custom_character_voice/Gary/Lec10.5-1135.wav

# %%
# 将所有音频（无论是上传的还是从视频抽取的，必须是.wav格式）去噪
# !python denoise_audio.py
# 标注短音频
# !python short_audio_transcribe.py --languages "{PRETRAINED_MODEL}" --whisper_size large
# Out:
# Traceback (most recent call last):
#   File "long_audio_transcribe.py", line 1, in <module>
#     from moviepy.editor import AudioFileClip
# ModuleNotFoundError: No module named 'moviepy'
# 100%|█████████████████████████████████████| 2.87G/2.87G [02:28<00:00, 20.7MiB/s]
# Detected language: en
# So don't call me at 2 a.m., please.
# Detected language: en
# And that's what makes the reds all together, because those all correspond to the same digit.
# Detected language: en
# And now it generalizes deeper layers.
# Detected language: en
# And it's actually log r theta.
# Detected language: en
# Over here is when we go from writing the result to asking for the next input.
# Detected language: en
# sample from that, feed that back in, et cetera.
# Detected language: en
# since I rarely get this far in the class by this time.
# Detected language: en
# And so blood rushes to the spot and you can tell where things were active.
# Detected language: en
# But once you've changed your weights, I'm now in a new place on the air surface and I'm changing my weights from there.
# Detected language: en
# I'm going to switch now.
# Detected language: en
# Can I answer his question first, and then I'll answer your question?
# Detected language: en
# And you find out the value from the verb tower in the encoder.
# Detected language: en
# So they're really the same model, but they're getting two different inputs.
# Detected language: en
# So you take some layer of the network and you apply BatchNorm to that.
# Detected language: en
# And it turns out these fully connected layers, which take up huge amounts of memory, aren't that important.
# Detected language: en
# You couldn't get it to work for the second question?
# Detected language: en
# And then, so if we had more dimensions, we could easily get a linearly separable representation.
# Detected language: en
# And so each, let me move my mouse.
# Detected language: en
# And its job is to reproduce the image.
# Detected language: en
# And now I'm plotting those numbers.
# Detected language: en
# What's happening from left to right is they're being translated up and down from probably the middle picture.
# Detected language: en
# and this is again part of league play.
# Detected language: en
# Never spent that long on it before.
# Detected language: en
# Is this clear to everyone what's going on here?
# Detected language: en
# So if you have a rectified linear function like this, the slope is either 1 or 0.
# Detected language: en
# At the end, I'm going to go over the midterm that I posted on Piazza yesterday or day before, whenever it was.
# Detected language: en
# We're trying to model that underlying deterministic function with our network.
# Detected language: en
# And so those are various ways to augment the data.
# Detected language: en
# That's Hal White, who was in the economics department here.
# Detected language: en
# But X's are given to you by God in the training set.
# Detected language: en
# And so if we're doing average pooling, that's like having equal weights on all four. 0.25, 0.25, 0.25.
# Detected language: en
# Here's one that takes in a sequence of inputs and produces one output at the end.
# Detected language: en
# So we have local receptive fields, and we replicate them across the image. That gives us convolutions.
# Detected language: en
# So that can't be right. Because they have the same size input and output layers.
# Detected language: en
# So there are some efforts to reduce this.
# Detected language: en
# And so, and also learning frame by frame, you're not learning any temporal dynamics.
# Detected language: en
# Autoencoders are neural networks that take an input and try and reproduce that input on its output.
# Detected language: en
# You average over all of those.
# Detected language: en
# and then league exploiters that play everybody.
# Detected language: en
# Okay, that's fine.
# Detected language: en
# And it's going to be in a particular location in the input.
# Detected language: en
# So I'm going to give you the simplest possible form of reinforcement learning.
# Detected language: en
# That's something I haven't told you how to compute.
# Detected language: en
# So you could have little filters and bigger filters and bigger filters.
# Detected language: en
# And so it had the board as input.
# Detected language: en
# So up here is where the character is going to come out.
# Detected language: en
# She looks kind of OK this way, but whoops, not so OK.
# Detected language: en
# OK, this should look familiar to those of you doing coding theory in ECE.
# Detected language: en
# They have multiple attention heads, and they basically have a KQV attention mechanism.
# Detected language: en
# E is 1, 1, 1 for this case.
# Detected language: en
# and that'll generalize to new faces.
# Detected language: en
# So it never really quite gets to zero or one.
# Detected language: en
# and I use the rest of the mini-batches negative examples.
# Detected language: en
# All of these should map to the same representation.
# Detected language: en
# I mean, if it ends up being that way, it ends up being that way.
# Detected language: en
# So my former high school intern, Brendan Lake, who's now a faculty at NYU, that's how old I am.
# Detected language: en
# But it gave us these kind of global, weird-looking receptive fields of the units.
# Detected language: en
# And then we have the height number coming in, and there's this weight.
# Detected language: en
# So the key question for us is whether we want to start a global AI arms race or prevent it from starting.
# Detected language: en
# for a quadratic like this.
# Detected language: en
# and some early approaches that were in the bottom of that graph before.
# Detected language: en
# Heon had been telling the computer vision people for years that they were going to learn their features.
# Detected language: en
# I had to turn my numeric grades into letter grades.
# Detected language: en
# And so this is the distribution of the monkey. This is the PDF of the monkey grades.
# Detected language: en
# Okay, what about C?
# Detected language: en
# And the decoder is a lot simpler than the encoder.
# Detected language: en
# So one of my favorite results here is why the fuselage face area is recruited for other tasks.
# Detected language: en
# You get the weight changes for the whole feature map.
# Detected language: en
# they call it ImageNet because they keep thinking it's a network.
# Detected language: en
# And as I mentioned before, notice the number of different feature channels gets bigger and bigger the deeper you go.
# Detected language: en
# Like this is spinal tap.
# Detected language: en
# So again, we're going to evaluate it by training a linear classifier.
# Detected language: en
# So this is an autoregressive model.
# Detected language: en
# and it's going to determine where that separating line is.
# Detected language: en
# This guy is going to have a different set of weights because its delta is different. But they're going to be exactly the same because it's multiplied times 0.5 to change.
# Detected language: en
# They tried changing the aspect ratio of the image.
# Detected language: en
# So we figure out what the output delta is.
# Detected language: en
# So, so far we've been doing.
# Detected language: en
# So what we did was we trained on a subset of the training set until it converged.
# Detected language: en
# So it's trying to emit actions.
# Detected language: en
# And Herb Simon said, machines will be capable in 20 years of doing any work that a man can do.
# Detected language: en
# One of the things to notice about this compare... So these are... There's multiple lines here because there's multiple networks.
# Detected language: en
# and you can get features at different scales that way.
# Detected language: en
# It uses one-hot encodings of letters.
# Detected language: en
# But always good fun for a project, reinforcement learning.
# Detected language: en
# So you're always trying to learn an estimate from an estimate.
# Detected language: en
# How does it lead to cross-entropy for logistic regression?
# Detected language: en
# So I'm going to not do this on the board. I'll do it on the slides.
# Detected language: en
# Max pooling in VGG, strided convolution, average pooling in dense net.
# Detected language: en
# You only have one output going up or down.
# Detected language: en
# OK, what's true about GANs? Are they unsupervised?
# Detected language: en
# So you're basically running the network backwards. You're taking the deltas and you're propagating them backwards.
# Detected language: en
# that j is linear.
# Detected language: en
# And initially, there's not much going on. They're just maybe counting pixels.
# Detected language: en
# In retirement, I got three grants last year.
# Detected language: en
# Momentum does not care about the alignment of the axes.
# Detected language: en
# Again, you're just adding noise and then trying to reverse that noise.
# Detected language: en
# You're trying to maximize this guy.
# Detected language: en
# And the last question is, I'm a little bit curious, like, how do you train the pictures when you do the convolution?
# Detected language: en
# That's basically where chat GPT is, right?
# Detected language: en
# I assume they don't back propagate into the memory, but they might block the gradient from there.
# Detected language: en
# And if it's like 86.5, then I add two points to everybody's grade.
# Detected language: en
# And so as you get deeper and deeper in the network, it's still all organized in what we would say is retinotopic coordinates.
# Detected language: en
# And then, so you get this weighted sum of the inputs.
# Detected language: en
# So this is taking your neighbor and just averaging you together.
# Detected language: en
# So if I say I like my coffee with cream and dog, you're surprised, because you expected me to say sugar.
# Detected language: en
# So look, how do I, I can't do it concurrently.
# Detected language: en
# And the goal is, now this is not used.
# Detected language: en
# a typical clustering algorithm is unsupervised.
# Detected language: en
# 20,000 was the limit to keep things about the right, so that they're relatively equal in number.
# Detected language: en
# I took 151B last quarter.
# Detected language: en
# What's wrong with correlated inputs?
# Detected language: en
# So that's crossover and mutation like genetic algorithms.
# Detected language: en
# So perceptrons didn't have hidden units, but Rosenblatt assumed nonlinear pre-processing.
# Detected language: en
# If you've searched under that move, then you can cache all that search and now do an even better search.
# Detected language: en
# now. We want these two people to be mapped to different output vectors.
# Detected language: en
# So even if it's a totally random binary image, you end up with smooth areas like this.
# Detected language: en
# One of the networks was a slightly different version of the other.
# Detected language: en
# And the way he did that was by simply copying the output back to the input and then having a set of weights that went into the hidden layer.
# Detected language: en
# You're trying to drive it away from fake data.
# Detected language: en
# discussed is basically you make your nose do this and you get these heavy creases here.
# Detected language: en
# And what they found was that color and cropping, cropping and color worked the best.
# Detected language: en
# If this output is zero, nothing gets through.
# Detected language: en
# OK, and for w0, the weight of the input's always active.
# Detected language: en
# So anyway, OK, so what is unit one of pure encoding?
# Detected language: en
# nickel and dime things.
# Detected language: en
# it turned out to be pretty damn hard for the students.
# Detected language: en
# So I advise you to wear masks even though it's not required anymore.
# Detected language: en
# thinks this is a baseball, and you can see why it might think that. It looks like the stitches on a baseball.
# Detected language: en
# So let's see, 306.
# Detected language: en
# So Atari games are an old video game console thing.
# Detected language: en
# So the first one is gonna be the forward-forward algorithm.
# Detected language: en
# It's whatever the network needs to remember.
# Detected language: en
# and you took the vector of the hidden unit activations for all occurrences of...
# Detected language: en
# And then you show the monkey in the network a new image that neither one's seen before.
# Detected language: en
# And you move over one pixel, you get another one. You move over one pixel, you get another one.
# Detected language: en
# In 2D, that looks like an ellipse.
# Detected language: en
# to imagine robots that were good.
# Detected language: en
# even though I proved it to him. Okay. In email.
# Detected language: en
# It's been used to learn all sorts of things.
# Detected language: en
# I think it's going to happen in the next 50 years. I'll be dead, luckily, but you won't, so you better be ready for it.
# Detected language: en
# So it's still recognizing this as a two mostly, even though there's all kinds of stuff going across it.
# Detected language: en
# It basically always produced the same Barack Obama picture.
# Detected language: en
# And if white was right here, you'd have to roll a one to get off the board.
# Detected language: en
# So, how does this lead to sum squared error for regression?
# Detected language: en
# But cropping and color together gave the best results.
# Detected language: en
# And we're going to check each one of them.
# Detected language: en
# So yeah, so that's a good point.
# Detected language: en
# So within just that last layer, you're also representing the location in your general image within just like 6 by 6 or whatever.
# Detected language: en
# Suppose we have, just to make this concrete, suppose we have category three out of four outputs.
# Detected language: en
# And these can be convolutional, which is how we usually deal with image data.
# Detected language: en
# I just realized this, because it doesn't include your opponents.
# Detected language: en
# Suppose I'm trying to send three words over a channel.
# Detected language: en
# So 50% of the time I'm sending one bit, 50% of the time I'm sending two bits, and on average I'm sending one and a half bits.
# Detected language: en
# So you choose a node to expand by the Q value, which is what the network outputs plus this exploration term.
# Detected language: en
# But on the content addressable memory, do you have to read the entire memory out first to get the scoring done? Yeah.
# Detected language: en
# And then they can communicate with each other through multiple steps.
# Detected language: en
# That goes up to now 11.
# Detected language: en
# There's a superior temporal sulcus for emotional things.
# Detected language: en
# In order to do that, I think we need to take a lot more inspiration from the brain.
# Detected language: en
# It's a sequential decision problem.
# Detected language: en
# I might be able to get around that local minimum because it's adding some stochasticity. In expectation.
# Detected language: en
# And that is what we did for many years in the 80s, because we didn't know any better.
# Detected language: en
# and they encode them with their locations. So they tell you where they are in the image.
# Detected language: en
# This guy is just going to be the slope of the activation function.
# Detected language: en
# And logistic regression.
# Detected language: en
# And the story there is a little complicated and I kind of alluded to it in my lecture, but I didn't really explain it.
# Detected language: en
# So you could generate a new video frame by frame by using CycleGAN on a per frame basis, right?
# Detected language: en
# And then we can apply gradient descent and repeat this process a gazillion times, where a gazillion is a lot.
# Detected language: en
# And that's the problem that LSTM solved.
# Detected language: en
# So yes, the answer is false.
# Detected language: en
# And if that small input is important, it'll take a long time for the network to learn to pay attention to it.
# Detected language: en
# and it's just got a couple of layers of weights to transform that.
# Detected language: en
# he suggests starting with a small momentum and increasing it.
# Detected language: en
# So you can use these to predict the next word.
# Detected language: en
# and I can't do anything now.
# Detected language: en
# but better as transformers, where you have the same network at each location joined by a tension.
# Detected language: en
# So there are 32 unique 64-dimensional vectors, because we've got 32 channels.
# Detected language: en
# you should have learned about today in section.
# Detected language: en
# And these are the results, which you can't see. So I blew one of them up.
# Detected language: en
# And again, this is built in operation.
# Detected language: en
# And again, as I said last time, if you put a square root over this, essentially what we're trying to do is for the whole training set is to get the outputs.
# Detected language: en
# And this is generally a good thing if your output categories are mutually exclusive.
# Detected language: en
# All right, so suppose our error surface, let's see.
# Detected language: en
# And now I'm trying to estimate the rewards from there.
# Detected language: en
# So it's picking what action type, when to do it, which units to apply it to, and where to, for example.
# Detected language: en
# And for zero, he turned on the first pixel.
# Detected language: en
# So it's not a good idea to learn to remember.
# Detected language: en
# You get some output of the hidden units, which I'll call z here.
# Detected language: en
# OK, so what's wrong with back prop?
# Detected language: en
# How do I know what its delta is? I have to know what the deltas here are, propagate them back until I get to here.
# Detected language: en
# and you would spend your time on the weekends figuring out some features, you'd come in on Monday.
# Detected language: en
# So they trained it on a problem where they had two inputs.
# Detected language: en
# Again, you have external input, external output.
# Detected language: en
# Given a state of the board, it's outputting probability over moves based on how good they look.
# Detected language: en
# We're going to define delta as minus the gradient of j with respect to the weighted sum of the inputs.
# Detected language: en
# And that's, again, the stupid thing we did for a few years.
# Detected language: en
# The main idea of ResNets is in the lower left corner here. I'm gonna have a one-to-one connection.
# Detected language: en
# And you can also imagine, you may not know this yet, but you can have them learn a program.
# Detected language: en
# It's greater than or equal to zero.
# Detected language: en
# So you're trying to minimize the error while minimizing the network.
# Detected language: en
# Nice, I don't know what makes them nice.
# Detected language: en
# So remember that stable diffusion does the same thing, diffusion models, but on latent representations.
# Detected language: en
# So again, what happened?
# Detected language: en
# You have a 2 3rds chance that your neighbor is right.
# Detected language: en
# No, I mean unique, one-dimensional vectors.
# Detected language: en
# So the neural Turing machine, the main idea is to add this structured memory to a neural controller that it can write to and read from.
# Detected language: en
# OK, so reading. This i is over every row of the memory.
# Detected language: en
# So let's see if this happens in practice.
# Detected language: en
# They're just trained to predict the next word.
# Detected language: en
# You probably have other questions.
# Detected language: en
# All right, one or two more here.
# Detected language: en
# So it's only true for autoregressive networks.
# Detected language: en
# So you're trying to minimize squared error between them or make the squared error between them go up if they're supposed to be different categories.
# Detected language: en
# and we're gonna get a good start on PA2 tonight.
# Detected language: en
# So why is sending something from the blue distribution less informative than sending something from the yellow distribution?
# Detected language: en
# And so we're going to get a similar kind of thing where the outgoing weights from each input will be the same.
# Detected language: en
# And you can think of each row of the weight matrix as being the weights to one of the outputs.
# Detected language: en
# They took this transcription of a six-year-old boy talking.
# Detected language: en
# And so that's a slightly different kind of search.
# Detected language: en
# This is audience participation.
# Detected language: en
# You're trying to train an oscillator, for example.
# Detected language: en
# So you've got everywhere there's a yellow block, that's a softmax.
# Detected language: en
# But if they're 5 by 5 patches, he's got, I don't know. This is 32 by 32.
# Detected language: en
# again. And these chapters in Dive Into Deep Learning might be off by one.
# Detected language: en
# And what he expects is that because max pooling works so well, it won't work quite as well as max pooling.
# Detected language: en
# There's a 3x3 patch for this one and a 3x3 patch for that one.
# Detected language: en
# All right, so let's just pretend that that's all we know about reinforcement learning.
# Detected language: en
# not quite as good as supervised learning, but getting there.
# Detected language: en
# Pixels depend most on nearby pixels, locality.
# Detected language: en
# So if you have discrete states in action, it can be a big, I guess this is a tensor.
# Detected language: en
# And so the closest zebra-like thing it can build from this is just turning the horse into a zebra.
# Detected language: en
# So these are very large pixels.
# Detected language: en
# and they used a resonant with batch norm.
# Detected language: en
# If we're good programmers, we just have one set of weights, but we keep reusing them over and over.
# Detected language: en
# I worked on facial expressions early in the day, faces, etc.
# Detected language: en
# So if we're very confident, if we think, yeah, this is gonna be a one, and wrong, it's gonna take a long time to get over that.
# Detected language: en
# But things kept going like that.
# Detected language: en
# No. Make an unbalanced tennis set more balanced.
# Detected language: en
# And it's actually a weighted sum between the two.
# Detected language: en
# And this is the result of a simulation one of my students did years ago.
# Detected language: en
# either that same layer or a previous layer.
# Detected language: en
# you could have one by one convolutions.
# Detected language: en
# And so you can see what's going on.
# Detected language: en
# And so you do all this work and you get a graph.
# Detected language: en
# And then the Q values for the state you just came from will be updated based on that.
# Detected language: en
# And the key difference between these is that for stable diffusion models, they don't operate in pixel space.
# Detected language: en
# you've got a Jennifer Aniston neuron.
# Detected language: en
# And in this case, there's a fairly simple way to do that.
# Detected language: en
# And that's Gil Scott-Heron.
# Detected language: en
# So yeah, so that's it.
# Detected language: en
# This also, Mike Jordan used this.
# Detected language: en
# So this image at the top was reconstructed.
# Detected language: en
# So he's going to make a recurrent net that he trains all at once.
# Detected language: en
# here I'm applying the chain rule again, over how the error goes down.
# Detected language: en
# And the green is convolution, pooling, and softmax.
# Detected language: en
# So the minimum of this is the same as the minimum of this without the sigma in there.
# Detected language: en
# The only successful neural network company for a long time was Robert Heck Nielsen's company.
# Detected language: en
# So that's much smaller, dimensional.
# Detected language: en
# So that's how it works.
# Detected language: en
# and make someone do or say something.
# Detected language: en
# And Jeff's approach is very useful when you don't have a target sequence.
# Detected language: en
# Okay, so again, down here is the gradient.
# Detected language: en
# But anyway, he trained it two different ways.
# Detected language: en
# And PCA provably minimizes the squared error of the data.
# Detected language: en
# and its job is to reproduce the whole image.
# Detected language: en
# one that takes an image from one domain and tries to generate an image from another domain.
# Detected language: en
# So what's wrong with this picture in the land of big data?
# Detected language: en
# So you're trying to minimize the squared error between the Q value for the state you just came from.
# Detected language: en
# So the perceptron will never converge.
# Detected language: en
# So I'm gonna go on to continents then if we're ready for that.
# Detected language: en
# It was just boy smash plate, girl like boy.
# Detected language: en
# So I want to lower weights to active inputs.
# Detected language: en
# That's also, I also call that the net input. G is the activation function, and we're gonna use the logistic activation function.
# Detected language: en
# usually has a larger central hidden layer than the input.
# Detected language: en
# Not necessarily, but the weights could be negative, right?
# Detected language: en
# And for midterms, you're allowed to bring a cheat sheet, 8.5 by 11 sheet of paper with notes on one side only.
# Detected language: en
# If you double the error derivatives at the output layer, all the error derivatives are gonna double.
# Detected language: en
# So I'm going to make 90 out of them, amplify my data set.
# Detected language: en
# And I'm just going to cut out the middle of this to illustrate the point.
# Detected language: en
# So this looks a lot like that.
# Detected language: en
# Well, it's an easy way to do it.
# Detected language: en
# So I don't think I have to do this twice because it went by so slow.
# Detected language: en
# basically what you're trying to do is you're trying to increase the output of the discriminator network.
# Detected language: en
# For those of you who couldn't hear her, she said, you could have the weights be one and the threshold be one.
# Detected language: en
# So then AlphaGo Zero came along.
# Detected language: en
# Any more questions? Any questions from who? How does backprop work in Q-learning?
# Detected language: en
# Okay, here's another clicker question.
# Detected language: en
# What batch normalization does is z-score that weighted sum of its inputs over the mini-batch.
# Detected language: en
# So the y-axis is y2.
# Detected language: en
# They can see where you live, where you work.
# Detected language: en
# So you have a different gown for each one of these.
# Detected language: en
# So again, if the two inputs are from the same category, minimize the distance between them.
# Detected language: en
# And then you can do a grid search, essentially, where you just try a full grid of possible hyperparameters.
# Detected language: en
# And now my slides are not advancing.
# Detected language: en
# And that's a hallucination, because it's an estimate.
# Detected language: en
# And if I give the network 2, then I give it this one, too.
# Detected language: en
# So alpha's become big near the deepest layer early in training and then drop back to small values.
# Detected language: en
# And so that's how they trained this deep network by, it's called deep supervision.
# Detected language: en
# Let's take the gamma out so it all fits on one line.
# Detected language: en
# This innervates object and face areas.
# Detected language: en
# So let's look at these feature maps or activation maps.
# Detected language: en
# Then we're going to take in this column and remember that there was a carry. Then we're going to take this column and etc.
# Detected language: en
# False. That would be really surprising.
# Detected language: en
# Let's look at one without the answers.
# Detected language: en
# Please go buy a clicker. The web or the app for clickers.
# Detected language: en
# If you had a two hidden layer network, it'd be a relatively shallow network, right?
# Detected language: en
# and Joe Biden and sending him over here by the final layer.
# Detected language: en
# You need both a replicated feature across the image and some sort of spatial pooling.
# Detected language: en
# I think I played Net Talk for you, right?
# Detected language: en
# And then the second programming assignment is backprop with one or two hidden layers.
# Detected language: en
# So hopefully we get in some cool stuff after this.
# Detected language: en
# And then the softmax is trained after training the network to actually predict what this character is, right?
# Detected language: en
# Now that's not completely true.
# Detected language: en
# Then you're propagating the deltas backwards through the network.
# Detected language: en
# The discriminator can get way ahead of the generator, providing little feedback.
# Detected language: en
# But when you get uploaded, they have this big machine that's uploading your brain.
# Detected language: en
# So the error with respect to the weighted sum of the inputs is the sum.
# Detected language: en
# We've seen perceptrons, which produces this off-on response.
# Detected language: en
# And let's say we exactly turn half off.
# Detected language: en
# And then later in the network, you're pooling together larger things.
# Detected language: en
# You can produce a word or a sentence, or you can caption an image.
# Detected language: en
# I think. You need something.
# Detected language: en
# a little three-layer net that learns its weights adaptively.
# Detected language: en
# and it won't remember them because it doesn't have a memory.
# Detected language: en
# Like I like my coffee with cream and dog.
# Detected language: en
# This claim relies on a combination of two known research observations.
# Detected language: en
# Can you hear me? Go through the mic.
# Detected language: en
# But I was kind of surprised at first.
# Detected language: en
# So and this is showing that it's learned to linearly separate at least three of the categories.
# Detected language: en
# So these are the two outputs, right?
# Detected language: en
# So you compute the gradient, change the weights.
# Detected language: en
# If it's way better, this will be positive, and I'll increase the value of the action in the state I just came from.
# Detected language: en
# I mean, it's just amazing that it can do this.
# Detected language: en
# And LSTM units revolutionized recurrent networks, allowing them to learn all sorts of tasks.
# Detected language: en
# So how do you decide when to stop?
# Detected language: en
# But you can also use it in shallow networks.
# Detected language: en
# where to put them or where to target things.
# Detected language: en
# You get 10% off for a day late, 20% off for two days late, and 50% off for three days late, and more than that, 100%.
# Detected language: en
# then you back propagate that error into the network and change the weights.
# Detected language: en
# And that's where things like Lynette, or sorry, that's where things, well, that's where Lynette came from.
# Detected language: en
# There are still some artifacts in here.
# Detected language: en
# You don't have to write down as many numbers.
# Detected language: en
# About half of you are saying A and about half are saying B.
# Detected language: en
# As you'll see in your programming assignment.
# Detected language: en
# So the assumption of a Gaussian gave us this form.
# Detected language: en
# sadly, so cool victory.
# Detected language: en
# and that's good because your brain's a recurrent network and we're trying to do artificial intelligence.
# Detected language: en
# So this is temporal difference learning because this is a temporal difference error.
# Detected language: en
# So we know for the output units with the right activation function and objective function that that becomes t minus y.
# Detected language: en
# And what that means is what we hope to do with that is get a good sample of the data.
# Detected language: en
# But by going to the board, I have to slow down.
# Detected language: en
# So all vectors z, these guys that we get up here, are normalized to length 1.
# Detected language: en
# Remember, when we're changing the weight, we need the delta of j.
# Detected language: en
# So the Atari player from DeepMind was yet another nature paper.
# Detected language: en
# Is it the owner or is it the machine itself?
# Detected language: en
# In PCA, the eigenvalue on that eigenvector is the variance along that eigenvector.
# Detected language: en
# and maybe they're 14 by 14.
# Detected language: en
# So if it was 0, 1, 0, 0, we'd add 0 and 1 and get 1.
# Detected language: en
# Now we've got six channels for six different feature maps.
# Detected language: en
# And then we've got BGAN. And this is when it started appearing in the newspapers.
# Detected language: en
# And computing the cross-correlation matrix, or the covariance matrix, is differentiable.
# Detected language: en
# And depending on the size of your filter, you might need padding around the outside.
# Detected language: en
# The max pooling operation when combined with convolution introduces some amount of translation invariance.
# Detected language: en
# Z is G of A.
# Detected language: en
# So that's where batch normalization comes in.
# Detected language: en
# Aside from the fact that it's a transformer. So here's the results.
# Detected language: en
# So you're looking ahead based on your estimates of how good things are.
# Detected language: en
# which has negative and positive outputs is better.
# Detected language: en
# The other thing you can do, and I tried to implement this and I don't think I ever got it right.
# Detected language: en
# You take similar images, you want them to be closer together than different images.
# Detected language: en
# So they do this thing called Monte Carlo tree search.
# Detected language: en
# And then we had two digits as input to two bit digits.
# Detected language: en
# And you can think of it as exploring an exponential number of models. And we'll see why that is.
# Detected language: en
# So when T of n is 1 and y of n is 1, the expression would be 0.
# Detected language: en
# Yeah, so increasing M will push the clusters farther apart.
# Detected language: en
# So there's quite a bit of work on this.
# Detected language: en
# This is the feature map.
# Detected language: en
# And this is just replacing the net input with its expression.
# Detected language: en
# We have a demo face recognition that I will use in class.
# Detected language: en
# And then the final layer is going to be like a one-hot encoding of the targets.
# Detected language: en
# The loss for a positive pair is this. So a positive, oh wait.
# Detected language: en
# Because, jeez, that's not letting me do anything.
# Detected language: en
# So an SVM is a support vector machine, and it is basically a perceptron on steroids.
# Detected language: en
# And the function that computes those in the context of the other towers, the outputs of the other towers.
# Detected language: en
# And then Romel, Art Hinton, and Williams did an 8.38 auto encoder to illustrate backprop.
# Detected language: en
# You wanted a chance to make law. Well, here it is. Make it a good one.
# Detected language: en
# what units should be on in the output, right?
# Detected language: en
# And this can be used in cases where you want to know if something's different from what you experienced or not.
# Detected language: en
# Okay, so if you cheat on an assignment or a test, you'll get zero for that.
# Detected language: en
# And then I showed you this. And this one.
# Detected language: en
# That's 17 of you said that. You would get this wrong on a test.
# Detected language: en
# three by three features seem to work well.
# Detected language: en
# but what we actually see is a corrupted version of that, with that being the mean.
# Detected language: en
# So you give it a whole sentence and you might leave out one word somewhere and it has to fill in the missing word.
# Detected language: en
# S comma A led to S prime.
# Detected language: en
# independently identically distributed.
# Detected language: en
# And then Rommel-Haritz idea, w squared over w squared plus one or plus c, you can have some constant there.
# Detected language: en
# A single data, and forgive me, Commander, is a curiosity.
# Detected language: en
# There are many routine human tasks that can and will be automated.
# Detected language: en
# Because when I do that, I can just sum up the result, right?
# Detected language: en
# If we had E here, it would be called Nats.
# Detected language: en
# And you get these kind of salience maps, like where it's paying attention to.
# Detected language: en
# And so these are UCSD undergrads and grad students, and they're making the six basic facial expressions.
# Detected language: en
# These are always the same for one feature map.
# Detected language: en
# Sorry. It actually got better the shallower we went. But it still wasn't very good.
# Detected language: en
# And copies it, copies it, copies it.
# Detected language: en
# And you can think of autonomous weapons as the third revolution in warfare after gunpowder and nuclear arms.
# Detected language: en
# And then you can use that to say if you're right or wrong and get a percent correct.
# Detected language: en
# This is just a formula for the Gaussian distribution in one dimension.
# Detected language: en
# These are what you computed by DECOMNET.
# Detected language: en
# Almost everything in the world is Gaussian, right?
# Detected language: en
# And then he had a rating from one to five.
# Detected language: en
# And going, going, going, gone. And 72% of you would get it right.
# Detected language: en
# Since you can use an RNN for similar things that you would use a CNN.
# Detected language: en
# and then sum them up when we're done.
# Detected language: en
# So again, this is the picture of exactly what you do.
# Detected language: en
# And so the gradient is always the same.
# Detected language: en
# The problem is that you've got a learning rate.
# Detected language: en
# So it's got the truth table for NAND.
# Detected language: en
# further training made it not do that anymore.
# Detected language: en
# So training proceeds by giving the generator some random noise input, which leads to something usually junk as output.
# Detected language: en
# Those two should be the same, right?
# Detected language: en
# You cannot use mean pooling to achieve translation invariance.
# Detected language: en
# He says when he adds this one in, he gets worse results.
# Detected language: en
# There's a question in the chat. I'm confused about how it is a base for supervised learning.
# Detected language: en
# OK, so you sample from that distribution. If it's 0.8, you're likely to move up and less likely to move down, et cetera.
# Detected language: en
# So not all the bicycles are bicycles.
# Detected language: en
# whereas the Perceptron only has a 0 or 1 output.
# Detected language: en
# and then use the weights in the other direction, just like propagating the deltas.
# Detected language: en
# Number two is this one.
# Detected language: en
# So it's run for 10 iterations and negative examples are again just ones with incorrect labels.
# Detected language: en
# and not very much in the way of summarizing here.
# Detected language: en
# You can wear a mask, right?
# Detected language: en
# So it would take a space, a B, an A, an N, an A, an N, an A.
# Detected language: en
# And it's recording. I don't see the little record thing.
# Detected language: en
# The main point of telling you about Piazza is that the slides are there.
# Detected language: en
# What is delta associated with in this weight change rule?
# Detected language: en
# It's going to get people out of jobs, though, but it is going to do a lot of good things for us.
# Detected language: en
# the delta for the hidden units is always the slope of that activation function times the weighted sum of the deltas.
# Detected language: en
# Of course, if you look closely enough, you'll see some things don't look quite right.
# Detected language: en
# We're not propagating information from the past to the future.
# Detected language: en
# No. They're the outputs of the network.
# Detected language: en
# So this is his zip code recognizer for some reason.
# Detected language: en
# And so now it really has to learn some features that distinguish positive from negative inputs.
# Detected language: en
# Now here we're dropping layers 3 and 4, and that only drops a million parameters.
# Detected language: en
# It's a Gaussian distribution with the red line being the mean of that Gaussian.
# Detected language: en
# so they're not going to help distinguish among the images.
# Detected language: en
# meaning the rest is just noise that's not explainable.
# Detected language: en
# It says, deep learning works.
# Detected language: en
# Monte Carlo because Monte Carlo is a city with a lot of gambling.
# Detected language: en
# OK, so imagine that we're using sigmoidal activation functions in our units.
# Detected language: en
# so that it's not just playing against itself over and over again because then it would get into one of these vicious cycles.
# Detected language: en
# But in the end, and I don't expect you to answer this on a test.
# Detected language: en
# Lillian Lee, I think her last name is, has a really good podcast. Sorry.
# Detected language: en
# And so that's it.
# Detected language: en
# But one I think is that it's got this kind of built-in search with the rolling dice.
# Detected language: en
# So the class ends with a movie, a short movie.
# Detected language: en
# You take the two closest vectors, say by cosine or Euclidean distance, and you average those two together.
# Detected language: en
# And the next good idea was CycleGAN.
# Detected language: en
# We don't care exactly what the output is, but you can do this for any category and make it think it's that category.
# Detected language: en
# It's not even learning. It's too high.
# Detected language: en
# Or another example that we gave in class was going from handwriting to text.
# Detected language: en
# And this is the CAFE data set.
# Detected language: en
# Rommelhart, Hinton, and Williams originally derived a learning rule using squared error as the objective function.
# Detected language: en
# this is the text embedded in the photo of a car and now you give it a photo.
# Detected language: en
# The third most important thing is that it learns internal representations.
# Detected language: en
# and that way and switch drivers during the assignment.
# Detected language: en
# And then you look at the states you can get to from there. And you look at the states you can get to from there.
# Detected language: en
# OK, so that's what he did.
# Detected language: en
# Now the question is, I've got all of these hidden units.
# Detected language: en
# And they can also behave systematically, translating one sentence in one language into another.
# Detected language: en
# However, if you get COVID or your roommate gets COVID and you have to take care of him or you have to fly home because your grandfather got COVID and is dying.
# Detected language: en
# And then I can just interpolate between them.
# Detected language: en
# So they're starting to get a little bit more categorical.
# Detected language: en
# So this is your cross-validation thing.
# Detected language: en
# The reason is that there's a topological difference between the two.
# Detected language: en
# I don't have any new funny stories for you, good luck.
# Detected language: en
# And so that's what this is showing, is you shift it up or shift it down.
# Detected language: en
# So having more feature maps means you have more ways to separate the categories. You've got.
# Detected language: en
# So instead of our previous one, notice here the difference is.
# Detected language: en
# Now the generator is trying to minimize this expression.
# Detected language: en
# So it's a kind of average pooling.
# Detected language: en
# So what we're showing on top here is four different crops of the same image.
# Detected language: en
# OK, that's it for this lecture.
# Detected language: en
# Anyway, both of these have a square root of the fan in and the fan out in this case.
# Detected language: en
# So I think I might have asked this of you before.
# Detected language: en
# And I can learn gender with one hidden unit pretty well.
# Detected language: en
# but while it was a big team. So it's really a complicated system, not just one network.
# Detected language: en
# So since then, there's been several different systems that learned to play it.
# Detected language: en
# And I do that for every other guy here.
# Detected language: en
# and that leads to what our prop is.
# Detected language: en
# What's interesting about AlphaStar is it's an imperfect information game, unlike Go, where you can see the whole board.
# Detected language: en
# all right, but E is the best answer because we can do dimensionality reduction.
# Detected language: en
# I thought that was, who knew?
# Detected language: en
# And then information can be stored in the cell by having a write gate that allows input from the rest of the recurrent network.
# Detected language: en
# and they said, imagine this technology in public hands.
# Detected language: en
# So machine learning can now detect cancer.
# Detected language: en
# You don't have to label anything, right?
# Detected language: en
# So, which of those is it?
# Detected language: en
# by looking at the statistical regularities in the words.
# Detected language: en
# And what we want to do is find those parameters that maximize the likelihood of the data, maximize the probability of the data.
# Detected language: en
# And by having, we used to call this a localist representation.
# Detected language: en
# So right now you're doing a forward pass for the entire implicit.
# Detected language: en
# And we're going to design our network to have those properties, to reflect those properties.
# Detected language: en
# So I go from a three by three to a five by five. I could then go to seven by seven.
# Detected language: en
# So ConNets had some early successes.
# Detected language: en
# but it's got a value network that's looking at the current value of the board and that critiques what the agent does, the actor.
# Detected language: en
# So anyway, that's supposed to be a little bit of fun.
# Detected language: en
# And so there's a three by three patch for this one.
# Detected language: en
# And then I was going to go through some thoughts about the ethics of AI.
# Detected language: en
# Anything change between those two? No. OK.
# Detected language: en
# And then in the bottom is all the other pairs.
# Detected language: en
# Hopefully that clears up something.
# Detected language: en
# So we're not estimating the value yet. This is actual value. So these are made up, obviously.
# Detected language: en
# So that's where its memory is.
# Detected language: en
# when you send me an email and say I sent you an email, could you read it?
# Detected language: en
# Maybe all the way to the end of the game, or maybe just some depth.
# Detected language: en
# and instead of coming up with features that they apply when they get into work on Monday.
# Detected language: en
# So again, this is a review and some more remarks on.
# Detected language: en
# So that's in the front of your temporal lobe.
# Detected language: en
# OK, then that's GANs, autoencoders, neural Turing machines, recurrent networks, LSTMs.
# Detected language: en
# So CIFAR-10 is 32 by 32 images with 10 categories.
# Detected language: en
# Delta associated with the inputs, with the unit.
# Detected language: en
# OK, so how to train these big convolutional networks.
# Detected language: en
# And the policy takes in a state, and it produces a distribution over possible actions given that state.
# Detected language: en
# So a little bit of, required a bit of thought.
# Detected language: en
# Uh, let's see.
# Detected language: en
# You give the generator network random noise.
# Detected language: en
# Oh yeah, and there's a reference to his paper from 1956.
# Detected language: en
# This one computes a carry out of this place.
# Detected language: en
# Yes. So we had to do it.
# Detected language: en
# You compute the deltas at the output.
# Detected language: en
# So you're going to combine those two estimates of the value of a particular move.
# Detected language: en
# or you can push the red button, or you can move it in eight different directions and push the red button.
# Detected language: en
# It's not any different than what we've been doing.
# Detected language: en
# And so what the agent then learns is a policy, a function from states to action probabilities.
# Detected language: en
# with things at right angles to it.
# Detected language: en
# This one doesn't turn on because it's minus 3 plus 0, and you get minus 4.
# Detected language: en
# And ever since we got deep networks, they've been able to do amazing things.
# Detected language: en
# And that's Monte Carlo Tree Search.
# ...
# Detected language: en
# There's a separate latent seed.
# Detected language: en
# And then you can say they're the same, because you know they're the same.
# Detected language: en
# And again, the important thing in maximum likelihood is how you model the probability distribution of the data.
# Detected language: en
# So the weights, so this is an assumption.
# Detected language: en
# And when you do that, you feed back error.
# Detected language: en
# And you can do that for any game.
# Detected language: en
# Other combinations of these units will pick out other parts of the tree.
# Detected language: en
# So I'm going to let you go and finish this next week. So tomorrow night is the review for the final.
# Detected language: en
# And then the output would be a probability distribution over moves based on the board.
# Detected language: en
# So they have trouble dealing with long-range dependencies. And LSTMs have solved this. OK.
# Detected language: en
# I take the next two closest ones, average them together.
# Detected language: en
# if the keep gate is on. And then you can read out later if the read gate is on.
# Detected language: en
# Up and down is which way the R is going.
# Detected language: en
# This is another way of taking text and using it to classify images.
# Detected language: en
# But pretty interesting.
# Detected language: en
# And then the actual model was very complicated.
# Detected language: en
# He was a physics PhD student.
# Detected language: en
# So I might give you something like this on a test.
# Detected language: en
# So I do report you to the academic integrity office.
# Detected language: en
# This is linear probing, meaning you just use the last hidden layer of the network to bolt that bolt on a classifier on top.
# Detected language: en
# So negative examples are self-generated by using other characters from the 10.
# Detected language: en
# India recently passed laws biased against Muslims.
# Detected language: en
# Usually I'm doing small edits, so they're very similar.
# Detected language: en
# Skip to clicker question.
# Detected language: en
# record what their brain looks like averaged over all those objects.
# Detected language: en
# Don't worry, we'll just have human AI teams.
# Detected language: en
# And then just writing out what this is, we get the sum over I can't see it from here.
# Detected language: en
# And the generator wants to minimize it.
# Detected language: en
# And so conn nets don't make sense for this one.
# Detected language: en
# So any questions about this part?
# Detected language: en
# It throws away color and shape and things like that.
# Detected language: en
# It is a real-time strategy game, which means that you don't take turns, you play and you have to play fast.
# Detected language: en
# And then they had six units here and six units here, which had to learn features of those entities that are useful for solving the task.
# Detected language: en
# With probability 1 minus epsilon, you take the best action, the greedy action.
# Detected language: en
# when you're able to say that's a 2002 BMW Series 7.
# Detected language: en
# And you should use gradient descent with momentum.
# Detected language: en
# We'd see which ones perform the best, and then kind of mix them through crossover.
# Detected language: en
# Oh, you mean starting with 2% of the weights over and over again?
# Detected language: en
# And you'll see people talk about lodges.
# Detected language: en
# Learning on some patterns ruins learning on others because you're using the same weights to do the, you're changing the weights that are used for all the patterns.
# Detected language: en
# So putting all this together, the stable diffusion model takes both the latency and the text prompt as input.
# Detected language: en
# And that's what this is.
# Detected language: en
# you can have discrete and continuous reinforcement learning. Produces some action at time step t out of a set of possible actions.
# Detected language: en
# you would copy the output back.
# Detected language: en
# But you wouldn't know reading Shakespeare. You might think it is a word, and you just don't know it.
# Detected language: en
# It's not completely, it's not random uniformly at random.
# Detected language: en
# Except there must have been some differences in the pixels that you couldn't see because it could still go back to the original Donald Trump picture.
# Detected language: en
# So that's this Gaussian is the probability of the target given X zero.
# Detected language: en
# They're not quite as good as large over-parameterized networks trained on the same dataset, but they're pretty close.
# Detected language: en
# and traffic sign recognition better than humans.
# Detected language: en
# Mouinnie found that a facial detection algorithm couldn't find her face.
# Detected language: en
# And because it's a quadratic, it's a quadratic.
# Detected language: en
# Okay, and you can get all these games online.
# Detected language: en
# And again, every point in the space is pretty close to a face.
# Detected language: en
# It was much better to do the eight.
# Detected language: en
# and beta is one, that operation will produce an address vector that doesn't look very good.
# Detected language: en
# It was very nice to include me because we had some discussions.
# Detected language: en
# And then what's along the diagonal, is it's percent correct?
# Detected language: en
# You guys can see my screen again, right?
# Detected language: en
# tuned CNNs with just a few hidden layers get about 0.6% error on MNIST.
# Detected language: en
# So this is anger. I don't know if you can read from the back, but that says anger there.
# Detected language: en
# They're called residual networks, because all this guy has to learn is the residual, the difference between x and what its output.
# Detected language: en
# And then the last week or so, I cover what happened last week in deep learning.
# Detected language: en
# And so I should, if this is positive, then I should increase the weight.
# Detected language: en
# And these have a name, they're called Gabor filters.
# Detected language: en
# No, no, it's OK.
# Detected language: en
# If we're doing max pooling here, where we have four numbers and we just pick the maximum.
# Detected language: en
# The outputs of sequence of characters.
# Detected language: en
# You're continuously emitting actions, not taking turns.
# Detected language: en
# So there are really only 79 principal components.
# Detected language: en
# This is going to be very similar to what happened with some of the weighted sum of the inputs versus the input, except this time.
# Detected language: en
# So the first thing he does is he propagates activity all the way through the network.
# Detected language: en
# And then we could have, say, in this case, five different features.
# Detected language: en
# It's called a rollout because you're rolling dice.
# Detected language: en
# And they work the same way, using the same architecture as language transformers, with no convolutions at all.
# Detected language: en
# And the most expensive but best way to do it is leave one out, cross-validation, which we used to use when we had small data sets.
# Detected language: en
# You're learning by trial and error. You're just trying stuff and seeing what works.
# Detected language: en
# You have to just decide to stop at some point.
# Detected language: en
# And again, this is just assuming a deep linear network.
# Detected language: en
# The best way is to get more data or manufacture more data.
# Detected language: en
# So we did this, and then we put them in a race to see who wins.
# Detected language: en
# But normally, if you're using batch norm, the input on that line is pretty similar.
# Detected language: en
# Okay, and I can randomize them so they're not correlated with each other.
# Detected language: en
# a little peer instruction here.
# Detected language: en
# And we trained it to do this program.
# Detected language: en
# But anyway, if you know the value of a state and you have a model, then you know.
# Detected language: en
# you'll have as many weights as you have pixels.
# Detected language: en
# If you're only doing pairs of things, that pair gives the best results.
# Detected language: en
# So mapping time into the state of the network.
# Detected language: en
# I think you all would agree that we'll have AIs that are smarter than us in 10,000 years.
# Detected language: en
# and meg-responses of humans listening to sentences or reading sentences.
# Detected language: en
# This is somebody in the middle of the network, say. So we don't know what y ought to be.
# Detected language: en
# This is your motor control.
# Detected language: en
# because if the sine doesn't get it, the cosine will. Right? So it's convolutional.
# Detected language: en
# with logistic or softmax outputs, all it can generate is one thing, the expected value of the output given the input.
# Detected language: en
# kind of XOR solution.
# Detected language: en
# And what that means is you give it a set of inputs, positive and negative.
# Detected language: en
# And so now I'm going to go through the derivation of backprop.
# Detected language: en
# And then they tried to find an efficient training method for mapping between the image and the text.
# Detected language: en
# So if the output is one and it should be zero, lower weights to active inputs.
# Detected language: en
# I'm giving it a word at every time step.
# Detected language: en
# So there's standard way to do pooling is to do max pooling.
# Detected language: en
# And this is how it was actually implemented.
# Detected language: en
# If you do just two convolutions, you're basically doing a kind of linear combination of things.
# Detected language: en
# And that maybe says something about burgers. I don't know.
# Detected language: en
# Mayrab who did some of these slides.
# Detected language: en
# But I am. That's a neural network.
# Detected language: en
# And then it's too late for this guy to fix it, because he doesn't see the output of that.
# Detected language: en
# And you get a reinforcement signal that says, was that good or bad?
# Detected language: en
# Convergence with a multilayer nonlinear network indicates the network has found a local minima along the error surface.
# Detected language: en
# And sorry for you folks at home.
# Detected language: en
# And this, you know, so sweat equity.
# Detected language: en
# OK, so that's Inception.
# Detected language: en
# They want to find another.
# Detected language: en
# So you're essentially becoming a word expert, as it were.
# Detected language: en
# So that's for all histories.
# Detected language: en
# And if you have a thousand categories, you're gonna have a thousand of these.
# Detected language: en
# So you want, again, you want g here to be as binary as possible, so it's a logistic output.
# Detected language: en
# Adaptive weight changes are only going to deal with these axes, because they're changing the learning rate for a weight.
# Detected language: en
# And so you would not really expect it to do very well on these.
# Detected language: en
# So you just divide by the number of occurrences of the, and you get a probability distribution over the next word.
# Detected language: en
# z-scoring on the other hand shifts the mean of the inputs of the variables to zero
# Detected language: en
# So now they know your name, they know who you're friends with.
# Detected language: en
# All right, so last time we derived backprop. Just a quick zip through.
# Detected language: en
# And we're going to use small local receptive fields like Jan is using here.
# Detected language: en
# And that makes it hard to choose a single global learning rate.
# Detected language: en
# And then two layers of hidden units before the output.
# Detected language: en
# For if this was theta, we'd have 1, 1, 1.
# Detected language: en
# It had one binary input, a numeric input, and a binary input.
# Detected language: en
# Success in the real world is a little more complicated.
# Detected language: en
# And the goal is to develop a network that learns the distribution of the training data.
# Detected language: en
# So there's only two directions the weight can.
# Detected language: en
# It's going to be in Pepper Canyon Hall.
# Detected language: en
# So it's only making about four and a half moves per second.
# Detected language: en
# That is, they could gate input from the previous, from the encoder network.
# Detected language: en
# It's one set of numbers going into here and getting an activation out.
# Detected language: en
# They propagated the deltas and then they changed the weights here.
# Detected language: en
# It's not good for you because it means you didn't learn the material.
# Detected language: en
# You start with one layer above the input.
# Detected language: en
# You're just combining lots of deltas.
# Detected language: en
# Yes, you have said that. Commander, you have devoted your life to the study of cybernetics in general.
# Detected language: en
# And most people nowadays use something like Atom as their optimizer.
# Detected language: en
# I think I have a few more short answer, a few more multiple answer.
# Detected language: en
# So I'm going to make sure you know exactly how it works by making you program it yourself.
# Detected language: en
# uh... so yet so we're already done a little playing
# Detected language: en
# Jeff suggested this in the Forward-Forward paper. He said it's simple and it works fast.
# Detected language: en
# But if I as an input it's still Z.
# Detected language: en
# Remember that backprop is a linear operation.
# Detected language: en
# Because maybe I had a 0.6 output. I sampled it. I got a 1. That's going to make that 0.6 go up.
# Detected language: en
# If you have none come out, it's not a surprise.
# Detected language: en
# And these things are called points.
# Detected language: en
# because the mean of this weighted sum.
# Detected language: en
# Let's make some big in this.
# Detected language: en
# And some of the other large data sets have noisy labels like their JPEG name or the camera settings.
# Detected language: en
# neuron activities are sharpened by attention.
# Detected language: en
# And then we wrote down the likelihood.
# Detected language: en
# And this other guy only connected to the cat output.
# Detected language: en
# Last quarter or two quarters ago.
# Detected language: en
# And what curiosity means is that what an agent is looking for is things it's never seen before.
# Detected language: en
# And with blurring though, first we do that and then we take the max.
# Detected language: en
# You know, that surprised me because I like to think about how the brain works and we don't generate new brain.
# Detected language: en
# they want you to clean your hair twice for some reason. I think so you use twice as much shampoo and buy more.
# Detected language: en
# They're useful for all sorts of things. Our features are useful for all sorts of environments.
# Detected language: en
# So you train this on all of Shakespeare, and you get something that's about as understandable as Shakespeare.
# Detected language: en
# You give that to the network. You change the weights for that one.
# Detected language: en
# So it's obviously a stochastic game.
# Detected language: en
# Who's heard of the Markov property before?
# Detected language: en
# OK, so the tricky part here.
# Detected language: en
# But there were numbers on the tiles in an empty space.
# Detected language: en
# They know a lot more about computer vision than I do.
# Detected language: en
# They had two kids, Arthur and Victoria. Andrew and Christine had James.
# Detected language: en
# So there's local consistency.
# Detected language: en
# So it's the cosine between the key vector and every different memory vector.
# Detected language: en
# because he was the first science fiction author.
# Detected language: en
# So there's this other model you train to go from the clip text embedding to the image encoding.
# Detected language: en
# And if you've got big memory and big iron, you can do that.
# Detected language: en
# How many people have had any reinforcement learning?
# Detected language: en
# So but I highly recommend Andrej Karpathy's blog for how to train a neural network.
# Detected language: en
# It's very socially difficult.
# Detected language: en
# Yeah, so the gradient starts at the output. You're applying a linear operation over and over again.

# %%
ADD_AUXILIARY = True #@param {type:"boolean"}
if ADD_AUXILIARY:
  # %run preprocess_v2.py --add_auxiliary_data True --languages "{PRETRAINED_MODEL}"
else:
  # %run preprocess_v2.py --languages "{PRETRAINED_MODEL}"
# Out:
# Downloading: "https://github.com/r9y9/open_jtalk/releases/download/v1.11.1/open_jtalk_dic_utf_8-1.11.tar.gz"
# dic.tar.gz: 0.00B [00:00, ?B/s]
# Extracting tar file /home/ubuntu/.local/lib/python3.8/site-packages/pyopenjtalk/dic.tar.gz
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.673 seconds.
# Prefix dict has been built successfully.
# finished
